# %%
import pandas as pd
import numpy as np
import datetime as dt
from dateutil import parser

import zipfile
import os

# %%
run_locally = False
if run_locally:
    dataset_path = 'data/Airline_review.csv'
else:
    dataset_path = 'C:/Users/cvish/Desktop/Gemini/data/Airline_review.csv'
    
df = pd.read_csv(dataset_path, index_col=0)
df.head()
# Out:
#     Airline Name Overall_Rating                           Review_Title  \
# 0    AB Aviation              9                "pretty decent airline"
# 1    AB Aviation              1                   "Not a good airline"
# 2    AB Aviation              1         "flight was fortunately short"
# 3  Adria Airways              1    "I will never fly again with Adria"
# 4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               NaN
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended
# 0              3.0         yes
# 1              2.0          no
# 2              2.0          no
# 3              1.0          no
# 4              1.0          no

# %%
# Parse the date strings using dateutil.parser.parse
df['review_datetime'] = df['Review Date'].apply(lambda x: parser.parse(x))

# %%
df.head()
# Out:
#     Airline Name Overall_Rating                           Review_Title  \
# 0    AB Aviation              9                "pretty decent airline"
# 1    AB Aviation              1                   "Not a good airline"
# 2    AB Aviation              1         "flight was fortunately short"
# 3  Adria Airways              1    "I will never fly again with Adria"
# 4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               NaN
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended review_datetime
# 0              3.0         yes      2019-11-11
# 1              2.0          no      2019-06-25
# 2              2.0          no      2019-06-25
# 3              1.0          no      2019-09-28
# 4              1.0          no      2019-09-24

# %%
df.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# count  19016.000000         18911.000000      14500.000000    18378.000000
# mean       2.618374             2.871609          2.553586        2.353738
# min        0.000000             0.000000          0.000000        1.000000
# 25%        1.000000             1.000000          1.000000        1.000000
# 50%        3.000000             3.000000          2.000000        1.000000
# 75%        4.000000             4.000000          4.000000        4.000000
# max        5.000000             5.000000          5.000000        5.000000
# std        1.464840             1.604631          1.526314        1.595747
#
#        Inflight Entertainment  Wifi & Connectivity  Value For Money  \
# count            10829.000000          5920.000000     22105.000000
# mean                 2.179056             1.780405         2.451165
# min                  0.000000             0.000000         0.000000
# 25%                  1.000000             1.000000         1.000000
# 50%                  2.000000             1.000000         2.000000
# 75%                  3.000000             2.000000         4.000000
# max                  5.000000             5.000000         5.000000
# std                  1.488839             1.318800         1.594155
#
#                      review_datetime
# count                          23171
# mean   2019-04-11 06:37:33.126753280
# min              2002-01-06 00:00:00
# 25%              2017-01-14 12:00:00
# 50%              2020-01-13 00:00:00
# 75%              2022-12-08 00:00:00
# max              2023-07-27 00:00:00
# std                              NaN

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


# download nltk corpus (first time only)
nltk.download([
"names",
"stopwords",
"vader_lexicon",
"punkt",
"wordnet"
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import nltk
#       2 from nltk.sentiment.vader import SentimentIntensityAnalyzer
#       3 from nltk.corpus import stopwords
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\__init__.py:153
#     151 from nltk.tag import *
#     152 from nltk.tokenize import *
# --> 153 from nltk.translate import *
#     154 from nltk.tree import *
#     155 from nltk.sem import *
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\translate\__init__.py:24
#      22 from nltk.translate.bleu_score import sentence_bleu as bleu
#      23 from nltk.translate.ribes_score import sentence_ribes as ribes
# ---> 24 from nltk.translate.meteor_score import meteor_score as meteor
#      25 from nltk.translate.metrics import alignment_error_rate
#      26 from nltk.translate.stack_decoder import StackDecoder
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\translate\meteor_score.py:13
#      10 from itertools import chain, product
#      11 from typing import Callable, Iterable, List, Tuple
# ---> 13 from nltk.corpus import WordNetCorpusReader, wordnet
#      14 from nltk.stem.api import StemmerI
#      15 from nltk.stem.porter import PorterStemmer
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\corpus\__init__.py:64
#       9 """
#      10 NLTK corpus readers.  The modules in this package provide functions
#      11 that can be used to read corpus files in a variety of formats.  These
#    (...)
#      59
#      60 """
#      62 import re
# ---> 64 from nltk.corpus.reader import *
#      65 from nltk.corpus.util import LazyCorpusLoader
#      66 from nltk.tokenize import RegexpTokenizer
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\corpus\reader\__init__.py:57
#       1 # Natural Language Toolkit: Corpus Readers
#       2 #
#       3 # Copyright (C) 2001-2023 NLTK Project
#    (...)
#       6 # URL: <https://www.nltk.org/>
#       7 # For license information, see LICENSE.TXT
#       9 """
#      10 NLTK corpus readers.  The modules in this package provide functions
#      11 that can be used to read corpus fileids in a variety of formats.  These
#    (...)
#      54 isort:skip_file
#      55 """
# ---> 57 from nltk.corpus.reader.plaintext import *
#      58 from nltk.corpus.reader.util import *
#      59 from nltk.corpus.reader.api import *
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\corpus\reader\plaintext.py:20
#      16 from nltk.corpus.reader.util import *
#      17 from nltk.tokenize import *
# ---> 20 class PlaintextCorpusReader(CorpusReader):
#      21     """
#      22     Reader for corpora that consist of plaintext documents.  Paragraphs
#      23     are assumed to be split using blank lines.  Sentences and words can
#    (...)
#      29     overriding the ``CorpusView`` class variable.
#      30     """
#      32     CorpusView = StreamBackedCorpusView
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\nltk\corpus\reader\plaintext.py:42, in PlaintextCorpusReader()
#      32 CorpusView = StreamBackedCorpusView
#      33 """The corpus view class used by this reader.  Subclasses of
#      34    ``PlaintextCorpusReader`` may specify alternative corpus view
#      35    classes (e.g., to skip the preface sections of documents.)"""
#      37 def __init__(
#      38     self,
#      39     root,
#      40     fileids,
#      41     word_tokenizer=WordPunctTokenizer(),
# ---> 42     sent_tokenizer=nltk.data.LazyLoader("tokenizers/punkt/english.pickle"),
#      43     para_block_reader=read_blankline_block,
#      44     encoding="utf8",
#      45 ):
#      46     r"""
#      47     Construct a new plaintext corpus reader for a set of documents
#      48     located at the given root directory.  Example usage:
#    (...)
#      60         corpus into paragraph blocks.
#      61     """
#      62     CorpusReader.__init__(self, root, fileids, encoding)
#
# AttributeError: partially initialized module 'nltk' has no attribute 'data' (most likely due to a circular import)

# %%
# !unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/

# Define the paths
zip_file_path = "/usr/share/nltk_data/corpora/wordnet.zip"
extracted_folder_path = "/usr/share/nltk_data/corpora/"

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# Confirm extraction
print("File extracted successfully to:", extracted_folder_path)
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 extracted_folder_path = "/usr/share/nltk_data/corpora/"
#       7 # Unzip the file
# ----> 8 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#       9     zip_ref.extractall(extracted_folder_path)
#      11 # Confirm extraction
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\zipfile.py:1240, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1238 while True:
#    1239     try:
# -> 1240         self.fp = io.open(file, filemode)
#    1241     except OSError:
#    1242         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/share/nltk_data/corpora/wordnet.zip'

# %%
# create preprocess_text function
def preprocess_text(text):

    # Tokenize the text
    tokens = word_tokenize(text.lower())

    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]


    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text

start_time = dt.datetime.now()
print("Started text preprocessing at ", start_time)
df['Review'] = df['Review'].apply(preprocess_text)
end_time = dt.datetime.now()
elapsed_time = end_time - start_time
print("Finished text preprocessing at ", end_time)
print ("Text preprocessing completed. Elapsed time: ", elapsed_time)
# Out:
# Started text preprocessing at  2024-03-25 15:23:07.526524
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 21
#      19 start_time = dt.datetime.now()
#      20 print("Started text preprocessing at ", start_time)
# ---> 21 df['Review'] = df['Review'].apply(preprocess_text)
#      22 end_time = dt.datetime.now()
#      23 elapsed_time = end_time - start_time
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\cvish\Desktop\LLMAPP\venv\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 5, in preprocess_text(text)
#       2 def preprocess_text(text):
#       3
#       4     # Tokenize the text
# ----> 5     tokens = word_tokenize(text.lower())
#       7     # Remove stop words
#       8     filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
#
# NameError: name 'word_tokenize' is not defined

# %%
df
# Out:
#         Airline Name Overall_Rating                            Review_Title  \
# 0        AB Aviation              9                 "pretty decent airline"
# 1        AB Aviation              1                    "Not a good airline"
# 2        AB Aviation              1          "flight was fortunately short"
# 3      Adria Airways              1     "I will never fly again with Adria"
# 4      Adria Airways              1   "it ruined our last days of holidays"
# ...              ...            ...                                     ...
# 23166         ZIPAIR              1          "customer service is terrible"
# 23167         ZIPAIR              1                    "Avoid at all costs"
# 23168         ZIPAIR              3          "Will not recommend to anyone"
# 23169         ZIPAIR              6             "It was immaculately clean"
# 23170         ZIPAIR              1  "lost all of our money with no refund"
#
#                Review Date  Verified  \
# 0       11th November 2019      True
# 1           25th June 2019      True
# 2           25th June 2019      True
# 3      28th September 2019     False
# 4      24th September 2019      True
# ...                    ...       ...
# 23166        5th July 2022     False
# 23167        1st June 2022      True
# 23168        31st May 2022      True
# 23169        23rd May 2022      True
# 23170        20th May 2022      True
#
#                                                   Review       Aircraft  \
# 0        Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1       Moroni to Anjouan. It is a very small airline...           E120
# 2        Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3        Please do a favor yourself and do not fly wi...            NaN
# 4       Do not book a flight with this airline! My fr...            NaN
# ...                                                  ...            ...
# 23166   Bangkok to Tokyo. I’ve flown many low cost ai...            NaN
# 23167    Avoid at all costs. I booked flights to go f...            NaN
# 23168    Flight was leaving at 23.15 and after an hou...            NaN
# 23169   Zipair is JAL’s budget airline. They don’t ha...     Dreamliner
# 23170    They lied about connection in Narita and we ...            NaN
#
#       Type Of Traveller       Seat Type                             Route  \
# 0          Solo Leisure   Economy Class                  Moroni to Moheli
# 1          Solo Leisure   Economy Class                 Moroni to Anjouan
# 2          Solo Leisure   Economy Class               Anjouan to Dzaoudzi
# 3          Solo Leisure   Economy Class             Frankfurt to Pristina
# 4        Couple Leisure   Economy Class  Sofia to Amsterdam via Ljubljana
# ...                 ...             ...                               ...
# 23166    Couple Leisure   Economy Class                  Bangkok to Tokyo
# 23167      Solo Leisure   Economy Class                Singapore to Tokyo
# 23168          Business   Economy Class                  Bangkok to Tokyo
# 23169          Business  Business Class              Tokyo to Los Angeles
# 23170      Solo Leisure   Economy Class                Singapore to Tokyo
#
#            Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0       November 2019           4.0                  5.0               4.0
# 1           June 2019           2.0                  2.0               1.0
# 2           June 2019           2.0                  1.0               1.0
# 3      September 2019           1.0                  1.0               NaN
# 4      September 2019           1.0                  1.0               1.0
# ...               ...           ...                  ...               ...
# 23166       June 2022           2.0                  1.0               NaN
# 23167       June 2022           NaN                  NaN               NaN
# 23168        May 2022           2.0                  4.0               2.0
# 23169        May 2022           3.0                  4.0               3.0
# 23170        May 2022           NaN                  NaN               NaN
#
#        Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0                 4.0                     NaN                  NaN
# 1                 1.0                     NaN                  NaN
# 2                 1.0                     NaN                  NaN
# 3                 1.0                     NaN                  NaN
# 4                 1.0                     1.0                  1.0
# ...               ...                     ...                  ...
# 23166             1.0                     1.0                  1.0
# 23167             NaN                     NaN                  NaN
# 23168             1.0                     NaN                  NaN
# 23169             1.0                     2.0                  5.0
# 23170             1.0                     NaN                  NaN
#
#        Value For Money Recommended review_datetime
# 0                  3.0         yes      2019-11-11
# 1                  2.0          no      2019-06-25
# 2                  2.0          no      2019-06-25
# 3                  1.0          no      2019-09-28
# 4                  1.0          no      2019-09-24
# ...                ...         ...             ...
# 23166              1.0          no      2022-07-05
# 23167              1.0          no      2022-06-01
# 23168              2.0          no      2022-05-31
# 23169              5.0         yes      2022-05-23
# 23170              1.0          no      2022-05-20
#
# [23171 rows x 20 columns]

# %%
df.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# count  19016.000000         18911.000000      14500.000000    18378.000000
# mean       2.618374             2.871609          2.553586        2.353738
# min        0.000000             0.000000          0.000000        1.000000
# 25%        1.000000             1.000000          1.000000        1.000000
# 50%        3.000000             3.000000          2.000000        1.000000
# 75%        4.000000             4.000000          4.000000        4.000000
# max        5.000000             5.000000          5.000000        5.000000
# std        1.464840             1.604631          1.526314        1.595747
#
#        Inflight Entertainment  Wifi & Connectivity  Value For Money  \
# count            10829.000000          5920.000000     22105.000000
# mean                 2.179056             1.780405         2.451165
# min                  0.000000             0.000000         0.000000
# 25%                  1.000000             1.000000         1.000000
# 50%                  2.000000             1.000000         2.000000
# 75%                  3.000000             2.000000         4.000000
# max                  5.000000             5.000000         5.000000
# std                  1.488839             1.318800         1.594155
#
#                      review_datetime
# count                          23171
# mean   2019-04-11 06:37:33.126753280
# min              2002-01-06 00:00:00
# 25%              2017-01-14 12:00:00
# 50%              2020-01-13 00:00:00
# 75%              2022-12-08 00:00:00
# max              2023-07-27 00:00:00
# std                              NaN

# %%
df['Review']
# Out:
# 0          Moroni to Moheli. Turned out to be a pretty ...
# 1         Moroni to Anjouan. It is a very small airline...
# 2          Anjouan to Dzaoudzi. A very small airline an...
# 3          Please do a favor yourself and do not fly wi...
# 4         Do not book a flight with this airline! My fr...
#                                ...
# 23166     Bangkok to Tokyo. I’ve flown many low cost ai...
# 23167      Avoid at all costs. I booked flights to go f...
# 23168      Flight was leaving at 23.15 and after an hou...
# 23169     Zipair is JAL’s budget airline. They don’t ha...
# 23170      They lied about connection in Narita and we ...
# Name: Review, Length: 23171, dtype: object

# %%
df.isnull().sum()
# Out:
# Airline Name                  0
# Overall_Rating                0
# Review_Title                  0
# Review Date                   0
# Verified                      0
# Review                        0
# Aircraft                  16042
# Type Of Traveller          3738
# Seat Type                  1096
# Route                      3828
# Date Flown                 3754
# Seat Comfort               4155
# Cabin Staff Service        4260
# Food & Beverages           8671
# Ground Service             4793
# Inflight Entertainment    12342
# Wifi & Connectivity       17251
# Value For Money            1066
# Recommended                   0
# review_datetime               0
# dtype: int64

# %%
# Impute null values in 'Aircraft' column with 'Unknown'
df['Aircraft'].fillna('Unknown', inplace=True)

# Impute null values in 'Type Of Traveller' column with 'Unknown'
df['Type Of Traveller'].fillna('Unknown', inplace=True)

# Impute null values in 'Seat Type' column with 'Unknown'
df['Seat Type'].fillna('Unknown', inplace=True)

# Impute null values in 'Route' column with 'Unknown'
df['Route'].fillna('Unknown', inplace=True)

# Impute null values in 'Date Flown' column with 'Unknown'
df['Date Flown'].fillna('Unknown', inplace=True)

# Impute null values in 'Seat Comfort' column with the mean of non-null values
mean_seat_comfort = df['Seat Comfort'].mean()
df['Seat Comfort'].fillna(int(mean_seat_comfort), inplace=True)

css = df['Cabin Staff Service'].mean()
df['Cabin Staff Service'].fillna(int(css), inplace=True)

fab = df['Food & Beverages'].mean()
df['Food & Beverages'].fillna(int(fab), inplace=True)

gs = df['Ground Service'].mean()
df['Ground Service'].fillna(int(gs), inplace=True)

# Impute null values in 'Value For Money' column with the mean of non-null values
mean_value_for_money = df['Value For Money'].mean()
df['Value For Money'].fillna(mean_value_for_money, inplace=True)

# Impute null values in 'Inflight Entertainment' column with 'Not Available'
df['Inflight Entertainment'].fillna('Not Available', inplace=True)

# Impute null values in 'Wifi & Connectivity' column with 'Not Available'
df['Wifi & Connectivity'].fillna('Not Available', inplace=True)

# You can continue imputing null values for other columns as needed

# Display the first few rows of the DataFrame to verify changes
print(df.head())
# Out:
#     Airline Name Overall_Rating                           Review_Title  \
# 0    AB Aviation              9                "pretty decent airline"
# 1    AB Aviation              1                   "Not a good airline"
# 2    AB Aviation              1         "flight was fortunately short"
# 3  Adria Airways              1    "I will never fly again with Adria"
# 4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...        Unknown
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...        Unknown
# 4   Do not book a flight with this airline! My fr...        Unknown
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               2.0
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service Inflight Entertainment Wifi & Connectivity  Value For Money  \
# 0             4.0          Not Available       Not Available              3.0
# 1             1.0          Not Available       Not Available              2.0
# 2             1.0          Not Available       Not Available              2.0
# 3             1.0          Not Available       Not Available              1.0
# 4             1.0                    1.0                 1.0              1.0
#
#   Recommended review_datetime
# 0         yes      2019-11-11
# 1          no      2019-06-25
# 2          no      2019-06-25
# 3          no      2019-09-28
# 4          no      2019-09-24
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Aircraft'].fillna('Unknown', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Type Of Traveller'].fillna('Unknown', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Seat Type'].fillna('Unknown', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Route'].fillna('Unknown', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Date Flown'].fillna('Unknown', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Seat Comfort'].fillna(int(mean_seat_comfort), inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin Staff Service'].fillna(int(css), inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Food & Beverages'].fillna(int(fab), inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ground Service'].fillna(int(gs), inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Value For Money'].fillna(mean_value_for_money, inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Inflight Entertainment'].fillna('Not Available', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Inflight Entertainment'].fillna('Not Available', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Wifi & Connectivity'].fillna('Not Available', inplace=True)
# C:\Users\cvish\AppData\Local\Temp\ipykernel_29604\3049379475.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Wifi & Connectivity'].fillna('Not Available', inplace=True)

# %%
df.isnull().sum()
# Out:
# Airline Name              0
# Overall_Rating            0
# Review_Title              0
# Review Date               0
# Verified                  0
# Review                    0
# Aircraft                  0
# Type Of Traveller         0
# Seat Type                 0
# Route                     0
# Date Flown                0
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Ground Service            0
# Inflight Entertainment    0
# Wifi & Connectivity       0
# Value For Money           0
# Recommended               0
# review_datetime           0
# dtype: int64

# %%
df.head()
# Out:
#     Airline Name Overall_Rating                           Review_Title  \
# 0    AB Aviation              9                "pretty decent airline"
# 1    AB Aviation              1                   "Not a good airline"
# 2    AB Aviation              1         "flight was fortunately short"
# 3  Adria Airways              1    "I will never fly again with Adria"
# 4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...        Unknown
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...        Unknown
# 4   Do not book a flight with this airline! My fr...        Unknown
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               2.0
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service Inflight Entertainment Wifi & Connectivity  Value For Money  \
# 0             4.0          Not Available       Not Available              3.0
# 1             1.0          Not Available       Not Available              2.0
# 2             1.0          Not Available       Not Available              2.0
# 3             1.0          Not Available       Not Available              1.0
# 4             1.0                    1.0                 1.0              1.0
#
#   Recommended review_datetime
# 0         yes      2019-11-11
# 1          no      2019-06-25
# 2          no      2019-06-25
# 3          no      2019-09-28
# 4          no      2019-09-24

# %%
df['Sentiment'] = df['Recommended'].apply(lambda x: 'Positive' if x == 'yes' else 'Negative')

# %%
df.isnull().sum()
# Out:
# Airline Name              0
# Overall_Rating            0
# Review_Title              0
# Review Date               0
# Verified                  0
# Review                    0
# Aircraft                  0
# Type Of Traveller         0
# Seat Type                 0
# Route                     0
# Date Flown                0
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Ground Service            0
# Inflight Entertainment    0
# Wifi & Connectivity       0
# Value For Money           0
# Recommended               0
# review_datetime           0
# Sentiment                 0
# dtype: int64

# %%
import spacy

# %%
# Load spaCy model for English
nlp = spacy.load("en_core_web_sm")
data=df['Review']
def extract_location_entities(review):
    doc = nlp(review)
    locations = [ent.text for ent in doc.ents if ent.label_ == "GPE"]  # GPE: geopolitical entity
    return locations
# Apply NER to each review and store the extracted entities in a new column
df["Location Entities"] = df["Review"].apply(extract_location_entities)

# %%
df['Location Entities']
# Out:
# 0                                        [Moheli]
# 1                                              []
# 2                                       [Comoros]
# 3                                        [Munich]
# 4                              [Sofia, Amsterdam]
#                            ...
# 23166    [Bangkok, Tokyo, Thailand, Japan, Japan]
# 23167                          [Singapore, Tokyo]
# 23168                                   [Bangkok]
# 23169                                          []
# 23170                            [Narita, Narita]
# Name: Location Entities, Length: 23171, dtype: object

# %%
# Replace invalid entries in 'Date Flown' column with NaN
df['Date Flown'] = df['Date Flown'].replace('Unknown', pd.NaT)

# Convert 'Date Flown' column to datetime with a specific format, ignoring NaN values
df['Date Flown'] = pd.to_datetime(df['Date Flown'], format='%B %Y', errors='coerce')

# Create a new column 'Travel Day' to extract the day of the week
df['Travel Day'] = df['Date Flown'].dt.day_name()

# Create a new column 'Weekend Travel' to indicate whether the travel day is a weekend or not
df['Weekend Travel'] = df['Travel Day'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

# %%
df.head()
# Out:
#     Airline Name Overall_Rating                           Review_Title  \
# 0    AB Aviation              9                "pretty decent airline"
# 1    AB Aviation              1                   "Not a good airline"
# 2    AB Aviation              1         "flight was fortunately short"
# 3  Adria Airways              1    "I will never fly again with Adria"
# 4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...        Unknown
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...        Unknown
# 4   Do not book a flight with this airline! My fr...        Unknown
#
#   Type Of Traveller      Seat Type                             Route  ...  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli  ...
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan  ...
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi  ...
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina  ...
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana  ...
#
#   Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0            4.0           Not Available        Not Available
# 1            1.0           Not Available        Not Available
# 2            1.0           Not Available        Not Available
# 3            1.0           Not Available        Not Available
# 4            1.0                     1.0                  1.0
#
#    Value For Money  Recommended review_datetime Sentiment   Location Entities  \
# 0              3.0          yes      2019-11-11  Positive            [Moheli]
# 1              2.0           no      2019-06-25  Negative                  []
# 2              2.0           no      2019-06-25  Negative           [Comoros]
# 3              1.0           no      2019-09-28  Negative            [Munich]
# 4              1.0           no      2019-09-24  Negative  [Sofia, Amsterdam]
#
#   Travel Day Weekend Travel
# 0     Friday        Weekday
# 1   Saturday        Weekend
# 2   Saturday        Weekend
# 3     Sunday        Weekend
# 4     Sunday        Weekend
#
# [5 rows x 24 columns]

# %%
df['Overall_Rating'] = pd.to_numeric(df['Overall_Rating'], errors='coerce')

# Calculate the length of each review
df['Review Length'] = df['Review'].apply(len)

# Create a new column for the Review Length to Rating Ratio
df['Review Length to Rating Ratio'] = df['Review Length'] / df['Overall_Rating']

# %%
df.head()
# Out:
#     Airline Name  Overall_Rating                           Review_Title  \
# 0    AB Aviation             9.0                "pretty decent airline"
# 1    AB Aviation             1.0                   "Not a good airline"
# 2    AB Aviation             1.0         "flight was fortunately short"
# 3  Adria Airways             1.0    "I will never fly again with Adria"
# 4  Adria Airways             1.0  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...        Unknown
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...        Unknown
# 4   Do not book a flight with this airline! My fr...        Unknown
#
#   Type Of Traveller      Seat Type                             Route  ...  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli  ...
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan  ...
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi  ...
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina  ...
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana  ...
#
#   Wifi & Connectivity  Value For Money  Recommended  review_datetime  \
# 0       Not Available              3.0          yes       2019-11-11
# 1       Not Available              2.0           no       2019-06-25
# 2       Not Available              2.0           no       2019-06-25
# 3       Not Available              1.0           no       2019-09-28
# 4                 1.0              1.0           no       2019-09-24
#
#    Sentiment   Location Entities Travel Day  Weekend Travel Review Length  \
# 0   Positive            [Moheli]     Friday         Weekday           352
# 1   Negative                  []   Saturday         Weekend           689
# 2   Negative           [Comoros]   Saturday         Weekend           405
# 3   Negative            [Munich]     Sunday         Weekend           734
# 4   Negative  [Sofia, Amsterdam]     Sunday         Weekend           597
#
#   Review Length to Rating Ratio
# 0                     39.111111
# 1                    689.000000
# 2                    405.000000
# 3                    734.000000
# 4                    597.000000
#
# [5 rows x 26 columns]

# %%
# Concatenate all columns into a new column named 'concatenated'
df['concatenated'] = df.apply(lambda row: ' '.join(row.astype(str)), axis=1)

# Create a new DataFrame containing only the 'concatenated' column
new_df = df[['concatenated']]

# Generate a new CSV file containing only the 'concatenated' column
new_df.to_csv('concatenated_data.csv', index=False)
